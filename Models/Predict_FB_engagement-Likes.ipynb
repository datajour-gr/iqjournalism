# %% [markdown]
# ## Random Forest Classifier for News dataset.

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import log_loss, confusion_matrix

import math
import matplotlib.pyplot as plt
# %matplotlib inline 
from datetime import datetime
# Import 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import accuracy_score
from sklearn.model_selection import RepeatedKFold

# %%
import time
import os
import ast
from datetime import datetime
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import numpy as np

import itertools
import re
import seaborn as sns

import nltk
from nltk.corpus import stopwords

# %%
from sklearn.metrics import confusion_matrix, f1_score

# %%
import sys

if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

# %%
pd.options.display.max_columns
pd.set_option("display.max_columns",100)

# %% [markdown]
# ### Import data

# %%
#data = pd.read_csv("../data/dataFACEBOOK.csv", thousands=',')
data = pd.read_csv("../../FINAL/data/dataFACEBOOK.csv", thousands=',')
#data['Total Interactions'] = data['Total Interactions'].replace(',','.', regex=True).astype(float)

# %%
data = data.rename(columns={'difficulty': 'Difficulty','title_polarity': 'Title polarity', 
                          'length':'Length', 'anger':'Anger' , 'positivity': 'Positivity',
       'joy':'Joy', 'disgust':'Disgust', 'surprise':'Surprise', 'trust':'Trust', 'anticipation':'Anticipation', 
                                'sadness':'Sadness',
      'fear':'Fear', 'numbers':'Numbers', 'polarity': 'Polarity', 'lexical richness': 'Lexical richness',
       'cosine': 'Cosine Similarity', 'sad':'Sad_', 'happy': 'Happy', 'inspired': 'Inspired', 
                                'dont_care':'I do not care', 'annoyed':'Annoyed', 'amused':'Amused',
       'afraid':'Afraid', 'sentence length':'Sentence length', 'mistakes':'Mistakes', 'adjectives':'Adjectives',
       'diversity':'Diversity', 'balance':'Balance',  'Strong_subjectivity':'Strong subjectivity',
       'Weak_subjectivity':'Weak subjectivity', 
       'Anger_intensity': 'Anger intensity', 'Joy_intensity':'Joy intensity', 
                                'Sadness_intensity':'Sadness intensity',
       'Fear_intensity':'Fear intensity', 'caps_body':'Capitals in article'})

# %%
data
data.shape
# Out:
# (73036, 93)

# %%
data.isnull().any()
# Out:
# url         False
# date        False
# author      False
# Title       False
# Noimages    False
#             ...
# 0            True
# 1            True
# "           False
# ?           False
# quality     False
# Length: 93, dtype: bool

# %% [markdown]
# data[data.isna().any(axis=1)]

# %%
data.columns
# Out:
# Index(['url', 'date', 'author', 'Title', 'Noimages', 'Publication', 'Length',
#        'Difficulty', 'uniq_wds', 'char_count', 'avg_word', 'perc_uniq',
#        'Sentence length', 'stopwords', 'Mistakes', '#links', 'Numbers',
#        'first_person', 'mtld', 'msttr', 'hdd', 'Capitals in article', 'Anger',
#        'Positivity', 'Joy', 'Disgust', 'Surprise', 'Trust', 'Anticipation',
#        'Sadness', 'negative', 'Fear', 'density', 'Sad_', 'Happy', 'Inspired',
#        'I do not care', 'Annoyed', 'Amused', 'Afraid', 'Polarity',
#        'negativity_vader', 'neutrality_vader', 'positivity_vader',
#        'subjectivity', 'No Celebs', 'Adjectives', 'cadence', 'No Animals',
#        'No Crime', 'No Sensual', 'Entertainment', 'Diversity',
#        'Total Interactions', 'Likes', 'Comments', 'Shares', 'Love', 'Wow',
#        'Haha', 'Sad', 'Angry', 'Care', 'Message', 'Link', 'Overperforming',
#        'Afinnity', 'Strong subjectivity', 'Weak subjectivity', 'Valence',
#        'Arousal', 'Dominance', 'Anger intensity', 'Joy intensity',
#        'Sadness intensity', 'Fear intensity', 'Yule_K', 'Title Polarity',
#        '#title_words', 'cursing', 'Message Polarity', 'Message cursing',
#        'Title cursing', 'Subjectivity Message', 'Subjectivity Title',
#        'Caps Title', 'Caps Message', '!', '0', '1', '"', '?', 'quality'],
#       dtype='object')

# %%
data = data[[ 'url', 'Noimages', 'Publication', 'Length', 'Difficulty', 'first_person','Capitals in article', 
             'Anger', 'Positivity', 'Joy', 'Disgust', 'Surprise', 'Trust', 'Anticipation', 'Sadness', 'negative', 
             'Fear', 'density', 'Sad_', 'Happy', 'Inspired', 'I do not care', 'Annoyed', 'Amused', 'Afraid', 
             'Polarity', 'No Celebs', 'Adjectives', 'No Animals', 'No Crime', 'No Sensual', 'Entertainment', 
             'Diversity', 'Total Interactions', 'Likes', 'Comments', 'Shares', 'Love', 'Wow', 'Haha', 'Sad', 
             'Angry', 'Care', 'Overperforming', 'Strong subjectivity', 'Valence', 'Arousal', 'Dominance', 
             'Anger intensity', 'Joy intensity', 'Sadness intensity', 'Fear intensity', '#title_words', 
             'cursing',  'Title cursing', 'Subjectivity Message', 'Message Polarity','Title Polarity',
             'Subjectivity Title', 'Caps Title', 'Caps Message', '!', '"', '?', 'quality'] ].copy()

# %%
print(data1.corr()["Likes"].abs().sort_values(ascending=False))
# Out:
# Likes                  1.000000
# quality                0.117504
# Dominance              0.110985
# Difficulty             0.094746
# Positivity             0.080608
# Trust                  0.075060
# Diversity              0.057909
# No Celebs              0.054325
# Adjectives             0.053537
# first_person           0.053518
# density                0.053145
# Sadness intensity      0.052339
# Valence                0.047262
# Length                 0.046832
# Fear intensity         0.043905
# Afraid                 0.043743
# Sad_                   0.043613
# Fear                   0.040108
# Surprise               0.036382
# Caps Title             0.035982
# Sadness                0.031792
# Inspired               0.028159
# Caps Message           0.024037
# Anticipation           0.022457
# Entertainment          0.020030
# Joy intensity          0.019100
# Joy                    0.017863
# Capitals in article    0.016402
# Strong subjectivity    0.016081
# ?                      0.015030
# Arousal                0.014641
# cursing                0.014353
# No Animals             0.012097
# No Crime               0.011892
# Disgust                0.011254
# !                      0.010401
# Annoyed                0.009773
# Amused                 0.009135
# Title cursing          0.008888
# I do not care          0.008558
# negative               0.008347
# No Sensual             0.008127
# #title_words           0.007798
# "                      0.007548
# Anger intensity        0.007521
# Polarity               0.006068
# Happy                  0.005601
# Anger                  0.000709
# Name: Likes, dtype: float64

# %%
data.isnull().sum().sum()
# Out:
# 36518

# %%
data= data.dropna()
data.shape
# Out:
# (36518, 65)

# %%
data['Likes'].describe([.80, .90, .91, .95])
# Out:
# count    36518.000000
# mean       771.780875
# std       2252.622123
# min          0.000000
# 50%        210.000000
# 80%        757.600000
# 90%       1565.000000
# 91%       1743.000000
# 95%       2970.900000
# max      77077.000000
# Name: Likes, dtype: float64

# %%
data['Likes'].describe([.10, .15, .05])
# Out:
# count    36518.000000
# mean       771.780875
# std       2252.622123
# min          0.000000
# 5%          34.000000
# 10%         49.000000
# 15%         63.000000
# 50%        210.000000
# max      77077.000000
# Name: Likes, dtype: float64

# %%
data['Likes'].describe()
# Out:
# count    36518.000000
# mean       771.780875
# std       2252.622123
# min          0.000000
# 25%         92.000000
# 50%        210.000000
# 75%        579.000000
# max      77077.000000
# Name: Likes, dtype: float64

# %%
data[data['Likes'] <7].shape
# Out:
# (19, 65)

# %%
data[data['Likes'] >2102].shape
# Out:
# (2702, 65)

# %%
data_good = data[data['Likes'] >2102] #'Total Interactions']>15000  ['Shares'] >1986
data_good.shape
# Out:
# (2702, 65)

# %%
data_good['engagement'] = 1

# %%
data_bad = data[data['Likes'] <7] 
data_bad.shape
# Out:
# (19, 65)

# %%
data_bad['engagement'] = 0

# %%
#data_bad2 = data_bad.sample(11442)

# %% [markdown]
# ## Concat the data

# %%
pdList = [data_bad, data_good]  # List of your dataframes
data= pd.concat(pdList)

# %%
data.shape
# Out:
# (2721, 66)

# %%
data['Subjectivity Title'] = pd.to_numeric(data['Subjectivity Title'], errors='coerce')

# %%
data['Subjectivity Message'] = pd.to_numeric(data['Subjectivity Message'], errors='coerce')

# %%
data.reset_index(drop=True, inplace=True)

# %%
features= ['Length', 'No Celebs', 'Arousal','Difficulty', 
           'Dominance', 
           'Anticipation', 'No Animals', 'Fear intensity',
           '#title_words']

# %%
features = ['Length', '#title_words', 'Dominance', 'Difficulty', 'No Celebs',
       'Diversity',
            'Anticipation', 'Arousal', 'Subjectivity Message',
       'Positivity', 'Fear', 'No Animals', 
            'Valence', 
            'Inspired', 'Polarity', 'No Crime']

# %%
data[features].describe()
# Out:
#              Length  #title_words    Dominance   Difficulty    No Celebs  \
# count   2721.000000   2721.000000  2721.000000  2721.000000  2721.000000
# mean     922.699375     11.156928     0.579918    43.352076     1.321205
# std      750.932275      4.061747     0.030508    10.307598     1.659561
# min      119.000000      1.000000     0.454047     1.000000     0.000000
# 25%      537.000000      9.000000     0.559973    37.000000     0.000000
# 50%      792.000000     11.000000     0.581877    43.000000     1.000000
# 75%     1156.000000     14.000000     0.600910    50.000000     2.000000
# max    18572.000000     25.000000     0.666813    77.000000    23.000000
#
#          Diversity  Anticipation      Arousal  Subjectivity Message  \
# count  2721.000000   2721.000000  2721.000000           2312.000000
# mean      6.418964      6.124152     0.468416              0.048820
# std       4.813827      2.432125     0.025199              0.049057
# min       0.000000      0.000000     0.337271              0.000000
# 25%       3.000000      4.391892     0.452313              0.000000
# 50%       6.000000      5.863192     0.468656              0.040000
# 75%       9.000000      7.569721     0.484755              0.071429
# max      80.000000     16.887417     0.562078              0.500000
#
#         Positivity         Fear   No Animals      Valence     Inspired  \
# count  2721.000000  2721.000000  2721.000000  2721.000000  2721.000000
# mean     14.199461     6.026973     1.392870     0.586981    10.799509
# std       4.154011     3.547052     4.603668     0.031749     3.488089
# min       1.980198     0.000000     0.000000     0.457253     0.854701
# 25%      11.428571     3.478261     0.000000     0.566296     8.433735
# 50%      13.924051     5.263158     0.000000     0.585976    10.457516
# 75%      16.640254     7.868852     1.000000     0.608246    12.745098
# max      49.400000    27.631579   160.000000     0.709097    30.104962
#
#           Polarity     No Crime
# count  2721.000000  2721.000000
# mean      0.899973     4.539508
# std       0.197220     6.993484
# min       0.000000     0.000000
# 25%       0.923000     1.000000
# 50%       0.985300     2.000000
# 75%       0.996100     5.000000
# max       1.000000    80.000000

# %%
import math
import matplotlib.pyplot as plt
# %matplotlib inline 

correlationMatrix = data[features].corr().abs()

plt.subplots(figsize=(15, 15))
sns.heatmap(correlationMatrix,annot=True)

# Mask unimportant features
sns.heatmap(correlationMatrix, mask=correlationMatrix < 1, cbar=False)
plt.show()

# %% [markdown]
# from scipy.cluster import hierarchy as hc
# from scipy import linalg, optimize
# import numpy as np
# import matplotlib as mpl
# import matplotlib.pyplot as plt
# import scipy
#
# corr = np.round(scipy.stats.spearmanr(data[features]).correlation, 5)
# corr_condensed = hc.distance.squareform(1-corr)
# z = hc.linkage(corr_condensed, method='average')
# fig = plt.figure(figsize=(20,15))
# dendrogram = hc.dendrogram(z, labels=data[features].columns, orientation='left', leaf_font_size=19)
# plt.show()

# %%
data.isnull().values.any()
# Out:
# True

# %%
data.isnull().sum().sum()
# Out:
# 1082

# %%
data.isnull().any()
# Out:
# url            False
# Noimages       False
# Publication    False
# Length         False
# Difficulty     False
#                ...
# !              False
# "              False
# ?              False
# quality        False
# engagement     False
# Length: 66, dtype: bool

# %%
#nan_rows = data[data['Fear_intensity'].isnull()]
#nan_rows

# %%
data = data.dropna()

# %%
data.to_csv("../../FINAL/data/dataFACEBOOKready.csv", index=False)

# %% [markdown]
# # Model construction starts here

# %%
X = data[features]
y = data['engagement']

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.20, random_state=10)

# %%
X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((3666, 23), (917, 23), (3666,), (917,))

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

lr.fit(X_train,y_train)

Y_pred_lr = lr.predict(X_val)

# %%
score_lr = round(accuracy_score(Y_pred_lr,y_val)*100,2)

print("The accuracy score achieved using Logistic Regression is: "+str(score_lr)+" %")
# Out:
# The accuracy score achieved using Logistic Regression is: 86.37 %

# %%
#f1_score(y_val, Y_pred_lr, average='weighted')

# %%
print('Classification Report\n', classification_report(y_val, Y_pred_lr))
# Out:
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86       444
#            1       0.90      0.83      0.86       473
#
#     accuracy                           0.86       917
#    macro avg       0.87      0.86      0.86       917
# weighted avg       0.87      0.86      0.86       917

# %%
# Import 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Ξεκινήστε τη λίστα βαθμολογίας μοντέλου
model_score = []
# Δημιουργήστε μια λίστα με τις πραγματικές τιμές
true_labels = []
# Δημιουργήστε τη λίστα των προβλεπόμενων τιμών
predicted_labels = []
# Ορίστε το αντικείμενο σταυροειδούς επαλήθευσης (cv)
our_cv = RepeatedKFold(n_splits=10, n_repeats=10)
# Ορίστε το Logistic Regression 
log_reg = LogisticRegression(penalty='none', random_state=123, solver='saga', max_iter = 10000, warm_start=True)
# Λούπα που παράχθηκε από τα κοψίματα του cv
for i_train, i_test in our_cv.split(X):
    # Ορίστε τα σετς
    X_train, X_val, y_train, y_val = X.iloc[i_train], X.iloc[i_test], y.iloc[i_train], y.iloc[i_test]
    # Fitting του logistic regression
    log_reg.fit(X_train, y_train.astype('int'))
#    importances = pd.DataFrame(data={
#    'Attribute': X_train.columns,
#    'Importance': model.coef_[0]
#    })
#    importances = importances.sort_values(by='Importance', ascending=False)
    # Πρόβλεψη των δεδομένων του testing σετ
    y_pred_test = log_reg.predict(X_val)
    # Λήψη βαθμολογίας ακρίβειας
    model_score.append(accuracy_score(y_val.astype('int'), y_pred_test.astype('int')))
    # Προσθέστε τις αληθινές τιμές στη λίστα
    true_labels.extend(y_val.astype('int'))
    # Προσθέστε τις προβλεπόμενες τιμές στη λίστα
    predicted_labels.extend(y_pred_test.astype('int'))

# %%
#Υπολογίστε τη μέση ακρίβεια κατά την 10 x 10 σταυροειδή επαλήθευση
# Χρήση του μέσου όρου για 100 τιμές μέσα στο model_score
print("Η μέση ακρίβεια του μοντέλου λογιστικής παλινδρόμησης είναι: "+str(np.mean(model_score))+" %")
# Out:
# Η μέση ακρίβεια του μοντέλου λογιστικής παλινδρόμησης είναι: 0.8485687511297582 %

# %%
from sklearn.metrics import confusion_matrix
# Υπολογισμός 
conf_mat = confusion_matrix(y_true=true_labels, y_pred=predicted_labels)
# Ορισμός των labels 
labels = ['Class 0', 'Class 1']
# Ξεκινήστε ένα άδειο σχήμα
fig = plt.figure()
# Προσθέστε άξονα στο σχήμα
ax = fig.add_subplot(111)
# Προσθέστε τον πίνακα
cax = ax.matshow(conf_mat, cmap=plt.cm.Blues)
# Εμφάνιση γραμμής χρωμάτων
fig.colorbar(cax)
# Αφαίρεση των x και y ticks
ax.set_xticklabels([''] + labels)
ax.set_yticklabels([''] + labels)
# Προσθέστε τα labels x και y
plt.xlabel('Predicted')
plt.ylabel('Expected')
# Προσθέστε νέα x και y ticks
for i in range(2):
    for j in range(2):
        ax.text(j, i, conf_mat[i, j], ha='center', va='center', color='r')
# Τυπώστε τον πίνακα
plt.show()

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
importances = pd.DataFrame(data={
    'Attribute': X_train.columns,
    'Importance': model.coef_[0]
})
importances = importances.sort_values(by='Importance', ascending=False)

# %%
plt.bar(x=importances['Attribute'], height=importances['Importance'], color='#087E8B')
plt.title('Feature importances obtained from coefficients', size=20)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# # SVM

# %%
from sklearn import svm

sv = svm.SVC(kernel='linear')

sv.fit(X_train, y_train)

Y_pred_svm = sv.predict(X_val)

# %%
f1_score(y_val, Y_pred_svm, average='weighted')
# Out:
# 0.8646288209606987

# %% [markdown]
# # Study the Decision Tree Classifier

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import RepeatedKFold

# %%
estimator = DecisionTreeClassifier(criterion='gini', splitter='best', 
max_depth=8, min_samples_split=500, min_samples_leaf=500, 
min_weight_fraction_leaf=0.0, max_features=None, random_state=None, max_leaf_nodes=None, 
 class_weight=None, ccp_alpha=0.0)

# %%
estimator.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=8, min_samples_leaf=500, min_samples_split=500)

# %%
val_pred_probs = estimator.predict_proba(X_val)

val_pred = estimator.predict(X_val)

# %%
f1_score(y_val, val_pred, average='macro')
# Out:
# 0.781128869537514

# %%
leave_id = estimator.apply(X_val)
print("The number of nodes is ", estimator.tree_.node_count)
# Out:
# The number of nodes is  13

# %%
dataplus = pd.concat([X_val.reset_index(),y_val.reset_index(),pd.DataFrame(val_pred_probs, columns=['prob0', 'prob1'])['prob1'], pd.DataFrame(leave_id, columns=['node'])], axis = 1) #.columns =['prob', 'node']

# %%
dataplus.shape
# Out:
# (458, 28)

# %% [markdown]
# # Study now the Random Forest Classifier

# %%
rf = RandomForestClassifier()

# %%
#Get the best RF Classifier from the grid

# %%
rf = RandomForestClassifier()
grid = {'min_samples_leaf' : [15, 20], 'max_features' : ['auto'], 
        'min_samples_split' : [   40, 60]
       }
clf = GridSearchCV(rf, grid, cv=5)
clf.fit(X_train, y_train)
#best_clf = clf.best_estimator_
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_features': ['auto'], 'min_samples_leaf': [15, 20],
#                          'min_samples_split': [40, 60]})

# %%
clf_val_pred_probs = clf.predict_proba(X_val)

clf_val_pred = clf.predict(X_val)

# %%
# Get the f1 Score of the best RF classifier of the grid

f1_score(y_val, clf_val_pred, average='macro')
# Out:
# 0.8908213665922917

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve

# %%
print(classification_report(y_val, clf_val_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.93      0.89       217
#            1       0.93      0.85      0.89       241
#
#     accuracy                           0.89       458
#    macro avg       0.89      0.89      0.89       458
# weighted avg       0.89      0.89      0.89       458

# %% [markdown]
# # Lets Try a RF classifier selecting manually the parameters

# %%
rf = RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=None, max_features='auto', max_leaf_nodes=None,
            min_samples_leaf=20, min_samples_split=40,
            min_weight_fraction_leaf=0.0, n_estimators=2000, n_jobs=1,
            oob_score=False, random_state=None, verbose=0,
            warm_start=False)

rf.fit(X_train, y_train)

val_pred_probs = rf.predict_proba(X_val)

val_pred = rf.predict(X_val)

# %%
train_pred_probs = rf.predict_proba(X_train)
train_pred = rf.predict(X_train)

# %%
log_loss(y_val, val_pred_probs, labels=rf.classes_)
# Out:
# 0.3129823553640845

# %%
log_loss(y_train, train_pred_probs, labels=rf.classes_)
# Out:
# 0.2673847059346316

# %%
f1_score(y_val, clf_val_pred, average='macro')
# Out:
# 0.8908213665922917

# %%
fi = pd.DataFrame(rf.feature_importances_, X_train.columns)
fi.columns = ['Importance']
fi.sort_values(by = 'Importance', ascending=False)[0:20]
# Out:
#                      Importance
# Length                 0.253622
# Dominance              0.136269
# #title_words           0.122984
# Difficulty             0.116932
# No Celebs              0.089629
# Trust                  0.056409
# density                0.036059
# Arousal                0.025272
# Adjectives             0.022544
# Anticipation           0.020229
# Fear intensity         0.018528
# Valence                0.016009
# Strong subjectivity    0.012537
# Joy intensity          0.010865
# Sadness intensity      0.010481
# Surprise               0.009145
# Afraid                 0.008965
# Happy                  0.007766
# No Crime               0.006927
# No Animals             0.005894

# %% [markdown]
# f1_score(y_val, val_pred, average='macro')

# %%
import matplotlib.pyplot as plt

plot = fi.sort_values(by = 'Importance', ascending=True).tail(15).plot.barh(figsize = (14,8), legend = False, title = 'Feature Importance', 
                                                                           )

#plt.title('Feature Importance')
plt.xlabel('Importance')
plt.ylabel('Features')

fig = plot.get_figure()
#fig.savefig('Importance_News_75.png')

# %%
print(__doc__)

import itertools
import numpy as np
import matplotlib.pyplot as plt

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, f1_score




def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
# Out:
# Automatically created module for IPython interactive environment

# %%
# Compute confusion matrix
#cnf_matrix = confusion_matrix(y_train, train_pred)

cnf_matrix = confusion_matrix(y_val, val_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=rf.classes_,
                      title='Confusion matrix')
# Out:
# Confusion matrix, without normalization
# [[199  18]
#  [ 37 204]]

# %%
# Check AGAIN the accurance of the manually defined RF classifier

f1_score(y_val, val_pred, average='macro')
# Out:
# 0.879898349853866

# %%
print(classification_report(y_val, clf_val_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.93      0.89       217
#            1       0.93      0.85      0.89       241
#
#     accuracy                           0.89       458
#    macro avg       0.89      0.89      0.89       458
# weighted avg       0.89      0.89      0.89       458

# %%
n_nodes = []
max_depths = []

for ind_tree in rf.estimators_:
    n_nodes.append(ind_tree.tree_.node_count)
    max_depths.append(ind_tree.tree_.max_depth)
    
print(f'Total number of Trees {int(len(rf.estimators_))}')
print(f'Average number of nodes {int(np.mean(n_nodes))}')
print(f'Average maximum depth {int(np.mean(max_depths))}')
# Out:
# Total number of Trees 2000
# Average number of nodes 157
# Average maximum depth 12

# %%
# visualizing the nth tree of the Random Forest (n=0)
import graphviz
from sklearn.tree import export_graphviz

#dot_data = export_graphviz(rf.estimators_[0])
graphviz.Source(export_graphviz(rf.estimators_[10],
                                out_file=None,
                                feature_names=features,
                                class_names=["0", "1"],
                                node_ids = True,
                                impurity=True))

# %%
MAX_ROUNDS = 180
OPTIMIZE_ROUNDS = True
LEARNING_RATE = 0.1
EARLY_STOPPING_ROUNDS = 55  
# Note: I set EARLY_STOPPING_ROUNDS high so that (when OPTIMIZE_ROUNDS is set)
#       I will get lots of information to make my own judgment.  You should probably
#       reduce EARLY_STOPPING_ROUNDS if you want to do actual early stopping.

# %%
import numpy as np
import pandas as pd
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
#from numba import jit
import time
import gc

# %%
# Compute gini

# from CPMP's kernel https://www.kaggle.com/cpmpml/extremely-fast-gini-computation
#@jit
def eval_gini(y_true, y_prob):
    y_true = np.asarray(y_true)
    y_true = y_true[np.argsort(y_prob)]
    ntrue = 0
    gini = 0
    delta = 0
    n = len(y_true)
    for i in range(n-1, -1, -1):
        y_i = y_true[i]
        ntrue += y_i
        gini += y_i * delta
        delta += 1 - y_i
    gini = 1 - 2 * gini / (ntrue * (n - ntrue))
    return gini

def gini_xgb(preds, dtrain):
    labels = dtrain.get_label()
    gini_score = -eval_gini(labels, preds)
    return [('gini', gini_score)]

# %%
# Set up classifier
model = XGBClassifier(    
                        n_estimators=MAX_ROUNDS,
                        max_depth=8,
                        objective="binary:logistic",
                        learning_rate=LEARNING_RATE, 
                        subsample=.8,
                        min_child_weight=6,
                        colsample_bytree=.8,
                        scale_pos_weight=1.6,
                        gamma=10,
                        reg_alpha=8,
                        reg_lambda=1.3,
                     )

# %%
fit_model_xgb = model.fit(X_train,y_train)

# %%
val_pred_xgb = fit_model_xgb.predict(X_val)

# %%
# Compute confusion matrix
#cnf_matrix = confusion_matrix(y_train, train_pred)

cnf_matrix = confusion_matrix(y_val, val_pred_xgb)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=rf.classes_,
                      title='Confusion matrix')
# Out:
# Confusion matrix, without normalization
# [[194  23]
#  [ 28 213]]

# %%
f1_score(y_val, val_pred_xgb, average='macro')
# Out:
# 0.8884543201386799

# %%
print(classification_report(y_val, clf_val_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.93      0.89       217
#            1       0.93      0.85      0.89       241
#
#     accuracy                           0.89       458
#    macro avg       0.89      0.89      0.89       458
# weighted avg       0.89      0.89      0.89       458

# %%
from sklearn.metrics import confusion_matrix

from sklearn.metrics import accuracy_score 
print ("Accuracy : ", accuracy_score(y_val, clf_val_pred))
# Out:
# Accuracy :  0.8908296943231441

# %%
import eli5
# Out:
# Using TensorFlow backend.

# %%
eli5.show_prediction(rf, X_val[features].iloc[0], show_feature_values=True)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=0
#
# </b>
#
#
#     (probability <b>0.813</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#                 <th style="padding: 0 0.5em 0 1em; text-align: right; border: none;">Value</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.473
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             1.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.15%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.148
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Length
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             292.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 93.57%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.094
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Dominance
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             0.525
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 95.40%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.058
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         #title_words
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             12.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 95.68%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.053
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Difficulty
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             54.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.09%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.046
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         No Celebs
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             0.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 97.43%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.025
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Adjectives
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             0.112
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 98.06%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.017
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Fear intensity
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             0.235
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 98.26%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.014
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Sadness intensity
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             0.304
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 98.62%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.010
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         No Crime
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             3.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 98.65%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.010
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         No Animals
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             0.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 99.34%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.004
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Disgust
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             8.284
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 99.46%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.003
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Arousal
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             0.465
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 99.50%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.002
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Joy intensity
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             0.162
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 99.72%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.001
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Anticipation
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             4.734
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 99.84%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.000
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         No Sensual
#     </td>

# %%
eli5.show_prediction(rf, X_val[features].iloc[1], show_feature_values=True)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=0
#
# </b>
#
#
#     (probability <b>0.609</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#                 <th style="padding: 0 0.5em 0 1em; text-align: right; border: none;">Value</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.473
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             1.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.56%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.187
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Length
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             278.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 94.89%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.067
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Arousal
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             0.519
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 95.07%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.064
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         No Celebs
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             0.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.75%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.035
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         #title_words
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             12.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 97.96%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.018
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Adjectives
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             0.124
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 98.02%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.017
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Fear intensity
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             0.239
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 98.16%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.016
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         No Crime
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             4.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 98.19%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.015
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         density
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             20.261
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 98.58%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.011
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Valence
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             0.542
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 99.25%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.004
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Subjectivity Title
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             0.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 99.27%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.004
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         No Animals
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             0.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 99.36%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.003
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Surprise
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             1.307
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 99.56%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.002
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         No Sensual
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             2.000
#         </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 99.68%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.001
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Disgust
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             1.307
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 99.55%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.002
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Happy
#     </td>

# %%
eli5.explain_prediction(rf, data[features].iloc[1])
# Out:
# Explanation(estimator='RandomForestClassifier(min_samples_leaf=20, min_samples_split=40,\n                       n_estimators=2000, n_jobs=1)', description='\nFeatures with largest coefficients.\n\nFeature weights are calculated by following decision paths in trees\nof an ensemble (or a single tree for DecisionTreeClassifier).\nEach node of the tree has an output score, and contribution of a feature\non the decision path is how much the score changes from parent to child.\nWeights of all features sum to the output score or proba of the estimator.\n\nCaveats:\n1. Feature weights just show if the feature contributed positively or\n   negatively to the final score, and does not show how increasing or\n   decreasing the feature value will change the prediction.\n2. In some cases, feature weight can be close to zero for an important feature.\n   For example, in a single tree that computes XOR function, the feature at the\n   top of the tree will have zero weight because expected scores for both\n   branches are equal, so decision at the top feature does not change the\n   expected score. For an ensemble predicting XOR functions it might not be\n   a problem, but it is not reliable if most trees happen to choose the same\n   feature at the top.\n', error=None, method='decision path', is_regression=False, targets=[TargetExplanation(target=1, feature_weights=FeatureWeights(pos=[FeatureWeight(feature='<BIAS>', weight=0.5266056969696961, std=None, value=1.0), FeatureWeight(feature='Length', weight=0.271471618033648, std=None, value=1244.0), FeatureWeight(feature='No Celebs', weight=0.10170788004386726, std=None, value=1.0), FeatureWeight(feature='Arousal', weight=0.02503204506942482, std=None, value=0.4146900000000001), FeatureWeight(feature='Strong subjectivity', weight=0.0183356743162451, std=None, value=0.028135048231511254), FeatureWeight(feature='No Animals', weight=0.01265536657376086, std=None, value=3.0), FeatureWeight(feature='Fear intensity', weight=0.012030681010991008, std=None, value=0.15266216216216213), FeatureWeight(feature='Valence', weight=0.008737361040334929, std=None, value=0.6150874999999999), FeatureWeight(feature='Sadness intensity', weight=0.007582001787296888, std=None, value=0.13631081081081084), FeatureWeight(feature='Afraid', weight=0.007084815086985815, std=None, value=9.060955518945637), FeatureWeight(feature='Subjectivity Title', weight=0.004963744757258503, std=None, value=0.0), FeatureWeight(feature='No Sensual', weight=0.0017736781824691506, std=None, value=1.0), FeatureWeight(feature='Disgust', weight=0.00028385200922519197, std=None, value=1.6474464579901154)], neg=[FeatureWeight(feature='Dominance', weight=-0.10872667116904279, std=None, value=0.5272574999999997), FeatureWeight(feature='Trust', weight=-0.09313956159793785, std=None, value=4.612850082372323), FeatureWeight(feature='Difficulty', weight=-0.08542188882626828, std=None, value=60.0), FeatureWeight(feature='#title_words', weight=-0.03679466168825527, std=None, value=9.0), FeatureWeight(feature='Adjectives', weight=-0.017419966712290486, std=None, value=0.13509060955518945), FeatureWeight(feature='density', weight=-0.015948091117412737, std=None, value=18.121911037891266), FeatureWeight(feature='Anticipation', weight=-0.008652536960213487, std=None, value=7.248764415156508), FeatureWeight(feature='Surprise', weight=-0.0033449388876890867, std=None, value=1.9769357495881383), FeatureWeight(feature='Happy', weight=-0.002051128853136149, std=None, value=11.86161449752883), FeatureWeight(feature='Joy intensity', weight=-0.0009239859318652465, std=None, value=0.20183783783783785), FeatureWeight(feature='No Crime', weight=-3.454084945906151e-05, std=None, value=4.0)], pos_remaining=0, neg_remaining=0), proba=0.6258064422876337, score=None, weighted_spans=None, heatmap=None)], feature_importances=None, decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
eli5.explain_weights(rf)
# Out:
# Explanation(estimator='RandomForestClassifier(min_samples_leaf=20, min_samples_split=40,\n                       n_estimators=2000, n_jobs=1)', description='\nRandom forest feature importances; values are numbers 0 <= x <= 1;\nall values sum to 1.\n', error=None, method='feature importances', is_regression=False, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature='x2', weight=0.25362210996086565, std=0.15752418442380964, value=None), FeatureWeight(feature='x1', weight=0.1362691184800458, std=0.13115495880207276, value=None), FeatureWeight(feature='x21', weight=0.12298375862370307, std=0.053573024267838595, value=None), FeatureWeight(feature='x0', weight=0.11693218453257764, std=0.10953414479195633, value=None), FeatureWeight(feature='x17', weight=0.08962885419066094, std=0.10728884632560222, value=None), FeatureWeight(feature='x12', weight=0.05640935590132701, std=0.07776213747260596, value=None), FeatureWeight(feature='x10', weight=0.03605948506595493, std=0.05532778578480577, value=None), FeatureWeight(feature='x4', weight=0.02527159985834087, std=0.020200028741551235, value=None), FeatureWeight(feature='x9', weight=0.022544495776672575, std=0.03495550351135271, value=None), FeatureWeight(feature='x7', weight=0.020228658303121986, std=0.014093550562892593, value=None), FeatureWeight(feature='x14', weight=0.018528104274121417, std=0.017646907941078493, value=None), FeatureWeight(feature='x3', weight=0.01600858752737665, std=0.0184038740603072, value=None), FeatureWeight(feature='x8', weight=0.012536502499831598, std=0.010167044135891907, value=None), FeatureWeight(feature='x6', weight=0.010864810353939554, std=0.009878348536547898, value=None), FeatureWeight(feature='x16', weight=0.01048094535393946, std=0.01652595614076953, value=None), FeatureWeight(feature='x11', weight=0.009145012577491785, std=0.008653230546785991, value=None), FeatureWeight(feature='x5', weight=0.008965386792579407, std=0.008908336459848584, value=None), FeatureWeight(feature='x13', weight=0.007765616672278716, std=0.007602481064690675, value=None), FeatureWeight(feature='x18', weight=0.006927133382418272, std=0.010130097870926313, value=None), FeatureWeight(feature='x20', weight=0.0058941275205797485, std=0.010437075415255705, value=None)], remaining=3), decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
eli5.show_weights(fit_model_xgb, top = 10,feature_names = features)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2065
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Length
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.52%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1052
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 No Celebs
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.67%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0917
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 #title_words
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.20%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0856
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Difficulty
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.29%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0846
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Dominance
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.97%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0373
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Arousal
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.34%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0341
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Anticipation
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.58%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0320
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Fear intensity
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.11%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0276
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Valence
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.23%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0267
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 No Crime
#             </td>
#         </tr>
#
#
#
#             <tr style="background-color: hsl(120, 100.00%, 95.23%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 13 more &hellip;</i>
#                 </td>
#             </tr>
#
#
#     </tbody>
# </table>

# %%
eli5.show_weights(rf, top = 10,feature_names = features)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2536
#
#                     &plusmn; 0.3150
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Length
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.05%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1363
#
#                     &plusmn; 0.2623
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Dominance
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.95%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1230
#
#                     &plusmn; 0.1071
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 #title_words
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.37%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1169
#
#                     &plusmn; 0.2191
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Difficulty
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.34%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0896
#
#                     &plusmn; 0.2146
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 No Celebs
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.02%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0564
#
#                     &plusmn; 0.1555
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Trust
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.89%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0361
#
#                     &plusmn; 0.1107
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 density
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.02%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0253
#
#                     &plusmn; 0.0404
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Arousal
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.33%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0225
#
#                     &plusmn; 0.0699
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Adjectives
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.59%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0202
#
#                     &plusmn; 0.0282
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Anticipation
#             </td>
#         </tr>
#
#
#
#             <tr style="background-color: hsl(120, 100.00%, 96.59%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 13 more &hellip;</i>
#                 </td>
#             </tr>
#
#
#     </tbody>
# </table>

# %%
#https://eli5.readthedocs.io/en/latest/blackbox/permutation_importance.html
from eli5.sklearn import PermutationImportance
perm = PermutationImportance(rf).fit(X_train,y_train)
eli5.show_weights(perm, top = 10,  feature_names = X_train.columns.tolist() )
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1118
#
#                     &plusmn; 0.0150
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Length
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 83.21%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0871
#
#                     &plusmn; 0.0099
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 #title_words
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.58%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0271
#
#                     &plusmn; 0.0040
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Difficulty
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.45%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0227
#
#                     &plusmn; 0.0032
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Dominance
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.93%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0158
#
#                     &plusmn; 0.0024
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 No Celebs
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.21%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0067
#
#                     &plusmn; 0.0017
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Anticipation
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.56%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0055
#
#                     &plusmn; 0.0022
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Arousal
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.98%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0042
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Adjectives
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.03%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0041
#
#                     &plusmn; 0.0031
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Fear intensity
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.32%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0032
#
#                     &plusmn; 0.0024
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Strong subjectivity
#             </td>
#         </tr>
#
#
#
#             <tr style="background-color: hsl(120, 100.00%, 98.32%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 13 more &hellip;</i>
#                 </td>
#             </tr>
#
#
#     </tbody>
# </table>

# %%
fit_model_xgb.fit(X_train, y_train)
PI = PermutationImportance(fit_model_xgb, scoring='f1_weighted').fit(X_val, y_val)
eli5.show_weights(PI, feature_names = X_train.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1321
#
#                     &plusmn; 0.0184
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Length
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 84.92%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0882
#
#                     &plusmn; 0.0278
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 #title_words
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.08%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0232
#
#                     &plusmn; 0.0176
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Difficulty
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.70%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0100
#
#                     &plusmn; 0.0116
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Anticipation
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.71%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0100
#
#                     &plusmn; 0.0153
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Arousal
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.01%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0087
#
#                     &plusmn; 0.0120
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Dominance
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.68%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0061
#
#                     &plusmn; 0.0033
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 No Crime
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.30%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0039
#
#                     &plusmn; 0.0064
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Strong subjectivity
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.54%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0031
#
#                     &plusmn; 0.0135
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 No Celebs
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.56%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0031
#
#                     &plusmn; 0.0045
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Surprise
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.03%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0017
#
#                     &plusmn; 0.0017
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Valence
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.04%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0017
#
#                     &plusmn; 0.0043
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Adjectives
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.39%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0009
#
#                     &plusmn; 0.0045
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Afraid
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.64%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0004
#
#                     &plusmn; 0.0058
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 No Animals
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0000
#
#                     &plusmn; 0.0039
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Joy intensity
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Sadness intensity
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.63%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0004
#
#                     &plusmn; 0.0051
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Trust
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.40%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0009
#
#                     &plusmn; 0.0022

# %%
#https://eli5.readthedocs.io/en/latest/blackbox/permutation_importance.html
from eli5.sklearn import PermutationImportance
perm = PermutationImportance(rf).fit(X_train,y_train)
eli5.show_weights(perm, top = 10,  feature_names = X_train.columns.tolist() )
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1084
#
#                     &plusmn; 0.0089
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Length
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 83.01%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0859
#
#                     &plusmn; 0.0077
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 #title_words
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.81%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0252
#
#                     &plusmn; 0.0072
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Difficulty
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.29%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0228
#
#                     &plusmn; 0.0011
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Dominance
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.63%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0166
#
#                     &plusmn; 0.0031
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 No Celebs
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.08%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0069
#
#                     &plusmn; 0.0030
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Anticipation
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.53%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0055
#
#                     &plusmn; 0.0019
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Arousal
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.87%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0044
#
#                     &plusmn; 0.0021
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Fear intensity
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.02%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0040
#
#                     &plusmn; 0.0034
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Trust
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.11%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0037
#
#                     &plusmn; 0.0011
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Adjectives
#             </td>
#         </tr>
#
#
#
#             <tr style="background-color: hsl(120, 100.00%, 98.11%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 13 more &hellip;</i>
#                 </td>
#             </tr>
#
#
#     </tbody>
# </table>

# %%
fit_model_xgb.fit(X_train, y_train)
PI = PermutationImportance(fit_model_xgb, scoring='f1_weighted').fit(X_val, y_val)
eli5.show_weights(PI, feature_names = X_train.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1475
#
#                     &plusmn; 0.0307
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Length
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 84.98%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0979
#
#                     &plusmn; 0.0105
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 #title_words
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.38%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0241
#
#                     &plusmn; 0.0047
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Difficulty
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.91%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0153
#
#                     &plusmn; 0.0107
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Arousal
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.58%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0118
#
#                     &plusmn; 0.0142
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Dominance
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.23%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0087
#
#                     &plusmn; 0.0111
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Anticipation
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.85%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0061
#
#                     &plusmn; 0.0089
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 No Crime
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.30%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0044
#
#                     &plusmn; 0.0073
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Adjectives
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.79%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0027
#
#                     &plusmn; 0.0070
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 No Celebs
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.95%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0022
#
#                     &plusmn; 0.0027
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Surprise
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.95%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0022
#
#                     &plusmn; 0.0073
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Strong subjectivity
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.27%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0013
#
#                     &plusmn; 0.0021
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Valence
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.45%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0009
#
#                     &plusmn; 0.0071
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Joy intensity
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.45%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0009
#
#                     &plusmn; 0.0021
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 No Sensual
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.66%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0004
#
#                     &plusmn; 0.0043
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 No Animals
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Sadness intensity
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.45%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0009
#
#                     &plusmn; 0.0021
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Subjectivity Title
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.27%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0013
#
#                     &plusmn; 0.0106

# %% [markdown]
# http://blog.datadive.net/random-forest-interpretation-with-scikit-learn/

# %%
from treeinterpreter import treeinterpreter as ti

# %%
prediction, bias, contributions = ti.predict(rf, X_val[features])

# %%
prediction
# Out:
# array([[0.59, 0.41],
#        [0.89, 0.11],
#        [0.15, 0.85],
#        [0.59, 0.41],
#        [0.56, 0.44],
#        [0.89, 0.11],
#        [0.53, 0.47],
#        [0.94, 0.06],
#        [0.44, 0.56],
#        [0.45, 0.55],
#        [0.15, 0.85],
#        [0.88, 0.12],
#        [0.73, 0.27],
#        [0.83, 0.17],
#        [0.79, 0.21],
#        [0.93, 0.07],
#        [0.91, 0.09],
#        [0.91, 0.09],
#        [0.61, 0.39],
#        [0.79, 0.21],
#        [0.89, 0.11],
#        [0.68, 0.32],
#        [0.89, 0.11],
#        [0.45, 0.55],
#        [0.64, 0.36],
#        [0.95, 0.05],
#        [0.88, 0.12],
#        [0.89, 0.11],
#        [0.87, 0.13],
#        [0.85, 0.15],
#        [0.86, 0.14],
#        [0.42, 0.58],
#        [0.79, 0.21],
#        [0.74, 0.26],
#        [0.83, 0.17],
#        [0.88, 0.12],
#        [0.95, 0.05],
#        [0.71, 0.29],
#        [0.48, 0.52],
#        [0.12, 0.88],
#        [0.72, 0.28],
#        [0.82, 0.18],
#        [0.5 , 0.5 ],
#        [0.27, 0.73],
#        [0.9 , 0.1 ],
#        [0.91, 0.09],
#        [0.93, 0.07],
#        [0.69, 0.31],
#        [0.77, 0.23],
#        [0.94, 0.06],
#        [0.91, 0.09],
#        [0.83, 0.17],
#        [0.76, 0.24],
#        [0.72, 0.28],
#        [0.3 , 0.7 ],
#        [0.78, 0.22],
#        [0.79, 0.21],
#        [0.74, 0.26],
#        [0.85, 0.15],
#        [0.33, 0.67],
#        [0.42, 0.58],
#        [0.89, 0.11],
#        [0.71, 0.29],
#        [0.88, 0.12],
#        [0.86, 0.14],
#        [0.72, 0.28],
#        [0.89, 0.11],
#        [0.89, 0.11],
#        [0.83, 0.17],
#        [0.89, 0.11],
#        [0.37, 0.63],
#        [0.91, 0.09],
#        [0.67, 0.33],
#        [0.96, 0.04],
#        [0.89, 0.11],
#        [0.92, 0.08],
#        [0.55, 0.45],
#        [0.85, 0.15],
#        [0.93, 0.07],
#        [0.91, 0.09],
#        [0.91, 0.09],
#        [0.62, 0.38],
#        [0.71, 0.29],
#        [0.78, 0.22],
#        [0.65, 0.35],
#        [0.12, 0.88],
#        [0.86, 0.14],
#        [0.82, 0.18],
#        [0.71, 0.29],
#        [0.62, 0.38],
#        [0.82, 0.18],
#        [0.86, 0.14],
#        [0.77, 0.23],
#        [0.85, 0.15],
#        [0.69, 0.31],
#        [0.87, 0.13],
#        [0.88, 0.12],
#        [0.66, 0.34],
#        [0.91, 0.09],
#        [0.52, 0.48],
#        [0.8 , 0.2 ],
#        [0.89, 0.11],
#        [0.89, 0.11],
#        [0.93, 0.07],
#        [0.42, 0.58],
#        [0.56, 0.44],
#        [0.95, 0.05],
#        [0.85, 0.15],
#        [0.75, 0.25],
#        [0.92, 0.08],
#        [0.71, 0.29],
#        [0.56, 0.44],
#        [0.53, 0.47],
#        [0.76, 0.24],
#        [0.72, 0.28],
#        [0.85, 0.15],
#        [0.71, 0.29],
#        [0.93, 0.07],
#        [0.85, 0.15],
#        [0.86, 0.14],
#        [0.77, 0.23],
#        [0.91, 0.09],
#        [0.9 , 0.1 ],
#        [0.81, 0.19],
#        [0.9 , 0.1 ],
#        [0.72, 0.28],
#        [0.75, 0.25],
#        [0.93, 0.07],
#        [0.96, 0.04],
#        [0.93, 0.07],
#        [0.38, 0.62],
#        [0.92, 0.08],
#        [0.94, 0.06],
#        [0.77, 0.23],
#        [0.86, 0.14],
#        [0.51, 0.49],
#        [0.66, 0.34],
#        [0.81, 0.19],
#        [0.77, 0.23],
#        [0.76, 0.24],
#        [0.51, 0.49],
#        [0.76, 0.24],
#        [0.88, 0.12],
#        [0.73, 0.27],
#        [0.87, 0.13],
#        [0.85, 0.15],
#        [0.92, 0.08],
#        [0.85, 0.15],
#        [0.82, 0.18],
#        [0.89, 0.11],
#        [0.66, 0.34],
#        [0.79, 0.21],
#        [0.68, 0.32],
#        [0.84, 0.16],
#        [0.85, 0.15],
#        [0.62, 0.38],
#        [0.63, 0.37],
#        [0.58, 0.42],
#        [0.85, 0.15],
#        [0.86, 0.14],
#        [0.9 , 0.1 ],
#        [0.74, 0.26],
#        [0.81, 0.19],
#        [0.65, 0.35],
#        [0.76, 0.24],
#        [0.7 , 0.3 ],
#        [0.9 , 0.1 ],
#        [0.91, 0.09],
#        [0.38, 0.62],
#        [0.91, 0.09],
#        [0.82, 0.18],
#        [0.68, 0.32],
#        [0.72, 0.28],
#        [0.59, 0.41],
#        [0.87, 0.13],
#        [0.84, 0.16],
#        [0.61, 0.39],
#        [0.66, 0.34],
#        [0.89, 0.11],
#        [0.96, 0.04],
#        [0.93, 0.07],
#        [0.83, 0.17],
#        [0.79, 0.21],
#        [0.87, 0.13],
#        [0.86, 0.14],
#        [0.84, 0.16],
#        [0.78, 0.22],
#        [0.39, 0.61],
#        [0.46, 0.54],
#        [0.65, 0.35],
#        [0.52, 0.48],
#        [0.67, 0.33],
#        [0.64, 0.36],
#        [0.77, 0.23],
#        [0.59, 0.41],
#        [0.78, 0.22],
#        [0.68, 0.32],
#        [0.89, 0.11],
#        [0.86, 0.14],
#        [0.88, 0.12],
#        [0.9 , 0.1 ],
#        [0.75, 0.25],
#        [0.66, 0.34],
#        [0.92, 0.08],
#        [0.87, 0.13],
#        [0.4 , 0.6 ],
#        [0.71, 0.29],
#        [0.46, 0.54],
#        [0.53, 0.47],
#        [0.72, 0.28],
#        [0.91, 0.09],
#        [0.91, 0.09],
#        [0.52, 0.48],
#        [0.95, 0.05],
#        [0.79, 0.21],
#        [0.27, 0.73],
#        [0.49, 0.51],
#        [0.22, 0.78],
#        [0.4 , 0.6 ],
#        [0.67, 0.33],
#        [0.  , 1.  ],
#        [0.19, 0.81],
#        [0.08, 0.92],
#        [0.47, 0.53],
#        [0.12, 0.88],
#        [0.44, 0.56],
#        [0.05, 0.95],
#        [0.01, 0.99],
#        [0.  , 1.  ],
#        [0.23, 0.77],
#        [0.05, 0.95],
#        [0.19, 0.81],
#        [0.29, 0.71],
#        [0.46, 0.54],
#        [0.01, 0.99],
#        [0.2 , 0.8 ],
#        [0.23, 0.77],
#        [0.23, 0.77],
#        [0.08, 0.92],
#        [0.14, 0.86],
#        [0.06, 0.94],
#        [0.12, 0.88],
#        [0.05, 0.95],
#        [0.26, 0.74],
#        [0.1 , 0.9 ],
#        [0.17, 0.83],
#        [0.71, 0.29],
#        [0.21, 0.79],
#        [0.82, 0.18],
#        [0.24, 0.76],
#        [0.44, 0.56],
#        [0.09, 0.91],
#        [0.22, 0.78],
#        [0.13, 0.87],
#        [0.16, 0.84],
#        [0.05, 0.95],
#        [0.  , 1.  ],
#        [0.29, 0.71],
#        [0.1 , 0.9 ],
#        [0.31, 0.69],
#        [0.15, 0.85],
#        [0.01, 0.99],
#        [0.71, 0.29],
#        [0.11, 0.89],
#        [0.16, 0.84],
#        [0.67, 0.33],
#        [0.08, 0.92],
#        [0.02, 0.98],
#        [0.07, 0.93],
#        [0.03, 0.97],
#        [0.13, 0.87],
#        [0.01, 0.99],
#        [0.09, 0.91],
#        [0.02, 0.98],
#        [0.2 , 0.8 ],
#        [0.41, 0.59],
#        [0.07, 0.93],
#        [0.02, 0.98],
#        [0.45, 0.55],
#        [0.01, 0.99],
#        [0.4 , 0.6 ],
#        [0.16, 0.84],
#        [0.47, 0.53],
#        [0.53, 0.47],
#        [0.67, 0.33],
#        [0.03, 0.97],
#        [0.41, 0.59],
#        [0.05, 0.95],
#        [0.23, 0.77],
#        [0.56, 0.44],
#        [0.15, 0.85],
#        [0.14, 0.86],
#        [0.2 , 0.8 ],
#        [0.43, 0.57],
#        [0.34, 0.66],
#        [0.33, 0.67],
#        [0.14, 0.86],
#        [0.85, 0.15],
#        [0.24, 0.76],
#        [0.62, 0.38],
#        [0.27, 0.73],
#        [0.61, 0.39],
#        [0.32, 0.68],
#        [0.36, 0.64],
#        [0.39, 0.61],
#        [0.62, 0.38],
#        [0.64, 0.36],
#        [0.43, 0.57],
#        [0.36, 0.64],
#        [0.47, 0.53],
#        [0.04, 0.96],
#        [0.28, 0.72],
#        [0.44, 0.56],
#        [0.82, 0.18],
#        [0.2 , 0.8 ],
#        [0.36, 0.64],
#        [0.33, 0.67],
#        [0.08, 0.92],
#        [0.1 , 0.9 ],
#        [0.33, 0.67],
#        [0.72, 0.28],
#        [0.39, 0.61],
#        [0.4 , 0.6 ],
#        [0.7 , 0.3 ],
#        [0.45, 0.55],
#        [0.87, 0.13],
#        [0.43, 0.57],
#        [0.5 , 0.5 ],
#        [0.43, 0.57],
#        [0.07, 0.93],
#        [0.14, 0.86],
#        [0.44, 0.56],
#        [0.09, 0.91],
#        [0.2 , 0.8 ],
#        [0.46, 0.54],
#        [0.41, 0.59],
#        [0.01, 0.99],
#        [0.49, 0.51],
#        [0.01, 0.99],
#        [0.41, 0.59],
#        [0.06, 0.94],
#        [0.32, 0.68],
#        [0.42, 0.58],
#        [0.38, 0.62],
#        [0.65, 0.35],
#        [0.36, 0.64],
#        [0.41, 0.59],
#        [0.5 , 0.5 ],
#        [0.13, 0.87],
#        [0.22, 0.78],
#        [0.48, 0.52],
#        [0.43, 0.57],
#        [0.3 , 0.7 ],
#        [0.7 , 0.3 ],
#        [0.15, 0.85],
#        [0.79, 0.21],
#        [0.39, 0.61],
#        [0.3 , 0.7 ],
#        [0.29, 0.71],
#        [0.37, 0.63],
#        [0.22, 0.78],
#        [0.72, 0.28],
#        [0.44, 0.56],
#        [0.34, 0.66],
#        [0.62, 0.38],
#        [0.29, 0.71],
#        [0.26, 0.74],
#        [0.28, 0.72],
#        [0.18, 0.82],
#        [0.33, 0.67],
#        [0.46, 0.54],
#        [0.26, 0.74],
#        [0.29, 0.71],
#        [0.08, 0.92],
#        [0.25, 0.75],
#        [0.71, 0.29],
#        [0.54, 0.46],
#        [0.45, 0.55],
#        [0.12, 0.88],
#        [0.06, 0.94],
#        [0.31, 0.69],
#        [0.05, 0.95],
#        [0.41, 0.59],
#        [0.24, 0.76],
#        [0.52, 0.48]])

# %%
prediction1, bias1, contributions1 = ti.predict(rf, X_val[features])

# %%
L = []

for pred, bias, contr in zip(prediction1, bias1, contributions1):
    d = {"pred0" : round(pred[0],2)}
    for c, feature in zip(contr,features):
       d.update({feature:round(c[0],2)})
#      print(feature, round(c[0],2))
    L.append(d)
ContributionsClass_df = pd.DataFrame(L)

# %%
plot = ContributionsClass_df[ContributionsClass_df['pred0']>0.5][features].mean().reindex(ContributionsClass_df[ContributionsClass_df['pred0']>0.5][features].mean().
           abs().sort_values(ascending=True).index).plot(kind='barh', figsize=(10,10))
fig = plot.get_figure()
#fig.savefig('Importance_News_tree for Class 0_75.png')

# %%
import matplotlib.pyplot as plt


plot = ContributionsClass_df[ContributionsClass_df['pred0']>0.5][features].mean().reindex(ContributionsClass_df[ContributionsClass_df['pred0']>0.5][features].mean().
           abs().sort_values(ascending=True).index).tail(10).plot(kind='barh', figsize=(5,4),color= 'grey')

plt.xlabel('Importance')
plt.ylabel('Features')

plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=True,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=True) # labels along the bottom edge are off
fig = plot.get_figure()
fig.savefig('Baseline.png', dpi=1000, bbox_inches='tight')
#fig.savefig('Importance_News_tree for Class 75.png')

# %%
L = []

for pred, bias, contr in zip(prediction1, bias1, contributions1):
    d = {"pred1" : round(pred[1],2)}
    for c, feature in zip(contr,features):
       d.update({feature:round(c[1],2)})
#      print(feature, round(c[0],2))
    L.append(d)
ContributionsClassOne_df = pd.DataFrame(L)

# %%
ContributionsClassOne_df[ContributionsClassOne_df['pred1']>0.5][features].mean().reindex(ContributionsClassOne_df[ContributionsClassOne_df['pred1']>0.5][features].mean().abs().sort_values(ascending=False).index)
# Out:
# #title_words           0.067073
# Length                 0.042683
# Diversity              0.032317
# No Celebs              0.031829
# Dominance              0.030610
# Difficulty             0.027073
# Trust                  0.012012
# density                0.007317
# first_person           0.006280
# Surprise               0.004024
# Anticipation           0.003963
# Afraid                 0.001951
# Adjectives             0.001829
# Sadness intensity      0.001646
# No Animals             0.001159
# Fear intensity         0.001098
# Subjectivity Title     0.000976
# Disgust               -0.000793
# Sad_                   0.000671
# Annoyed                0.000610
# Valence               -0.000610
# Inspired               0.000549
# Strong subjectivity    0.000427
# Joy intensity          0.000366
# Happy                  0.000366
# I do not care         -0.000366
# No Crime              -0.000244
# Arousal               -0.000183
# Caps Title             0.000000
# Caps Message           0.000000
# No Sensual             0.000000
# Amused                 0.000000
# "                      0.000000
# cursing                0.000000
# ?                      0.000000
# dtype: float64

# %%
plot = ContributionsClassOne_df[ContributionsClassOne_df['pred1']>0.5][features].mean().reindex(ContributionsClassOne_df[ContributionsClassOne_df['pred1']>0.5][features].mean().
           abs().sort_values(ascending=True).index).plot(kind='barh', figsize=(10,10))
fig = plot.get_figure()
#fig.savefig('Importance_News_tree for Class 1_75.png')

# %%
plot = ContributionsClassOne_df[ContributionsClassOne_df['pred1']<0.5][features].mean().reindex(ContributionsClassOne_df[ContributionsClassOne_df['pred1']>0.5][features].mean().
           abs().sort_values(ascending=True).index).tail(10).plot(kind='barh', figsize=(5,4),color= 'grey')
fig = plot.get_figure()
fig.savefig('Importance_News_tree_small for Class 1_75.png')
